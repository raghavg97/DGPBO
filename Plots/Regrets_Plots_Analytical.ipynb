# %%
import pyreadr
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import os

# %%
n_funcs = 6
n_algos = 5

regrets_mean_full = []
regrets_se_full = []

for i in range(n_funcs):
    regrets_mean_full.append([])
    regrets_se_full.append([])

# %%
##----------------------Regrets----------------------------------------------------------
##FUNCTION Art1
folder = './art1/'
file_label = 'art1'
d = 1
min_step = 2
max_step = 99


alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 98
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("ART1")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[0] = regret
regrets_se_full[0] = regret_se
#----------------------------------------------------------------------------------------------------

##FUNCTION Camel 6h
folder = './camel6h/'
file_label = 'camel6h'
d = 2
min_step = 5*d -1
max_step = 148

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']


reps = 10
steps = 149
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("Camel6h")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[1] = regret
regrets_se_full[1] = regret_se
#----------------------------------------------------------------------------------------------------
##FUNCTION Camel 3h
folder = './camel3h/'
file_label = 'camel3h'
d = 2
min_step = 5*d -1
max_step = 149

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 149
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("Camel3h")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[2] = regret
regrets_se_full[2] = regret_se
#---------------------------------------------------------------------------------------------
##FUNCTION Hartmann3
folder = './hart3/'
file_label = 'hart3'
d = 3
min_step = 5*d -1
max_step = 199
steps = 200

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']


reps = 10
steps = 200
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("hart3")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[3] = regret
regrets_se_full[3] = regret_se
#-------------------------------------------
##FUNCTION Hartmann4
folder = './hart4/'
file_label = 'hart4'
d = 4
min_step = 5*d -1
max_step = 199
steps = 200

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']


reps = 10
steps = 200
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("hart4")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[4] = regret
regrets_se_full[4] = regret_se
#-------------------------------------------
##FUNCTION Mich 10d #TEMPORRRRRRRRRARARARARARY
folder = './mich10/'
file_label = 'mich10'
d = 10
min_step = 5*d -1
max_step = 199

alg_labels = ['GP EI','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI EI']
regret_labels = ['GPEI','wgp','DGPBO_EI','MCMC_EI','DGPSIEI',]

time_labels = ['GPEI','WGP','EI','MCMC_EI','DGPSIEI']

reps = 5
steps = 200
regret = np.zeros((n_algos,steps-min_step))
regret_se = np.zeros((n_algos,steps-min_step))
i = 0
print("mich10d")
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    regret_data = np.array(data['regret_' + regret_labels[i]])[:,min_step:steps]
    regret[i,:] = np.mean(regret_data[:],axis = 0)
    regret_se[i,:] = np.std(regret_data[:],axis = 0)/np.sqrt(reps)
    i = i + 1
    print(i)

regrets_mean_full[5] = regret
regrets_se_full[5] = regret_se
#-------------------------------------------
# Out:
# ART1
# 1
# 2
# 3
# 4
# 5
# Camel6h
# 1
# 2
# 3
# 4
# 5
# Camel3h
# 1
# 2
# 3
# 4
# 5
# hart3
# 1
# 2
# 3
# 4
# 5
# hart4
# 1
# 2
# 3
# 4
# 5
# mich10d
# 1
# 2
# 3
# 4
# 5

# %%
plt_titles = ['Test Function (1D)','Six-Hump Camel Function','Three-Hump Camel Function','Hartmann3 Function','Hartmann4 Function','Michalewicz Function']
fig,axs = plt.subplots(3,2)
min_steps= [2,9,9,14,19,49]

symbols = ['-o','-p','-x',':','-*']
colors = ['b','m','g','k','r']

a = 25
b = 30
#--------------------------
idx = 0
ax = axs[0,0]
ax.figure.set_size_inches(a,b)

plt_labels = ['GP-BO','WGP-BO','DGP-DSVI-BO','DGP-MCMC-BO','DGP-SI-BO (Proposed)']


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)



# ax.set_yscale('log')

ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])
ax.set_ylim([-0.1,1e-1])



#----------------------------------------------------------------------------------------------
idx = 1
ax = axs[0,1]
ax.figure.set_size_inches(a,b)


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)
    


ax.set_yscale('log')

ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])



#------------------------------------------------------------------------------------------------------
idx = 2
ax = axs[1,0]
ax.figure.set_size_inches(a,b)


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)
    


ax.set_yscale('log')

ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])

ax.set_yscale('log')

#------------------------------------------------------------------------------------------------------
idx = 3
ax = axs[1,1]
ax.figure.set_size_inches(a,b)


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)



ax.set_yscale('log')

ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])


#------------------------------------------------------------------------------------------------------
idx = 4
ax = axs[2,0]
ax.figure.set_size_inches(a,b)


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)
    


ax.set_yscale('log')

ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])

ax.set_yscale('log')

#------------------------------------------------------------------------------------------------------
idx = 5
ax = axs[2,1]
ax.figure.set_size_inches(a,b)


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    # ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i+1],alpha=0.3)
    


# ax.set_yscale('log')
ax.legend(loc=1,fontsize = 20)
ax.set_ylabel('Simple Regret',fontsize = 24)
ax.set_xlabel('Number of Evaluations',fontsize=24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'x',labelsize = 20)
ax.tick_params(axis = 'y',labelsize = 20)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])

# ax.set_yscale('log')
 
fig.subplots_adjust(wspace = 0.15,hspace = 0.2)
plt.savefig('Analytical_Regrets.pdf', format='pdf',pad_inches=0,bbox_inches = 'tight')
# plt.savefig('Analytical_Regrets.svg', format='svg',transparent = True,pad_inches=0)

# %%
idx = 0
fig,ax = plt.subplots()
# ax.figure.set_size_inches(a,a)

plt_labels = ['GP-BO','WGP-BO','DGP-DSVI-BO','DGP-MCMC-BO','DGP-SI-BO (Proposed)']


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)



# ax.set_yscale('log')

ax.legend(loc=1,fontsize = 10)
ax.set_ylabel('Simple Regret',fontsize = 12)
ax.set_xlabel('Number of Evaluations',fontsize=12)
ax.set_title(plt_titles[idx],fontsize = 15)
ax.tick_params(axis = 'x',labelsize = 10)
ax.tick_params(axis = 'y',labelsize = 10)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])
# ax.set_ylim([-0.1,1e-1])
plt.savefig('1D_linear_review.pdf', format='pdf',pad_inches=0,bbox_inches = 'tight')

# %%
idx = 0
fig,ax = plt.subplots()
# ax.figure.set_size_inches(a,a)

plt_labels = ['GP-BO','WGP-BO','DGP-DSVI-BO','DGP-MCMC-BO','DGP-SI-BO (Proposed)']


for i in range(regrets_mean_full[idx].shape[0]):
    plt_x = min_steps[idx] + np.arange(regrets_mean_full[idx].shape[1])
    plt_y = regrets_mean_full[idx][i,:]
    plt_e_l =  regrets_mean_full[idx][i,:] - regrets_se_full[idx][i,:]
    plt_e_u =  regrets_mean_full[idx][i,:] + regrets_se_full[idx][i,:]
    ax.plot(plt_x,plt_y,symbols[i],color = colors[i],label = plt_labels[i],markersize = 3)
    ax.fill_between(plt_x,plt_e_l,plt_e_u,color = colors[i],alpha=0.3)



ax.set_yscale('log')

ax.legend(loc=1,fontsize = 10)
ax.set_ylabel('Simple Regret',fontsize = 12)
ax.set_xlabel('Number of Evaluations',fontsize=12)
ax.set_title(plt_titles[idx],fontsize = 15)
ax.tick_params(axis = 'x',labelsize = 10)
ax.tick_params(axis = 'y',labelsize = 10)

ax.set_xlim([min_steps[idx],min_steps[idx] + regrets_mean_full[idx].shape[1]])
ax.set_ylim([1e-10,1e-1])
plt.savefig('1D_log_review.pdf', format='pdf',pad_inches=0,bbox_inches = 'tight')

# %%
for idx in range(6):
    print(plt_titles[idx])
    for i in range(regrets_mean_full[idx].shape[0]):
        print(regrets_mean_full[idx][i,-1])
        # print(regrets_se_full[idx][i,-1])
# Out:
# Test Function (1D)
# -2.3033208403044904e-05
# 0.0004119917691729924
# 0.007894481591902014
# -2.3083267251400307e-05
# -2.2300952853471222e-05
# Six-Hump Camel Function
# 0.0024292460915550595
# 0.028329243474094046
# 0.09170420159556589
# 0.003156021510796525
# 0.0005577696230324447
# Three-Hump Camel Function
# 0.010803727583400513
# 0.11658406267339112
# 0.28303372052422454
# 0.031161896406334107
# 0.0020859667606877583
# Hartmann3 Function
# 0.07392261201641648
# 0.05554317273259781
# 0.2937426668732751
# 0.02226419570708633
# 0.0455527126934296
# Hartmann4 Function
# 0.12021911734901743
# 0.10293429136788013
# 0.5192594874864307
# 0.006997940325573682
# 0.057484354966087635
# Michalewicz Function
# 0.7145036383515991
# 0.7245252742487539
# 1.4919072396465165
# 1.0245200987732181
# 0.5888204924317006

# %%
time_mean_full = []

for i in range(n_funcs):
    time_mean_full.append([])

##----------------------Time---------------------------------------------------------
##FUNCTION Art1
folder = './art1/'
file_label = 'art1'
d = 1
min_step = 2
max_step = 99


alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 98


i = 0
print("ART1")

time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    
    time_data = np.array(data['runtime_' + time_labels[i]])[:,min_step:steps]
    time_data= np.nan_to_num(time_data)
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[0] = time
#----------------------------------------------------------------------------------------------------

##FUNCTION Camel 6h
folder = './camel6h/'
file_label = 'camel6h'
d = 2
min_step = 5*d -1
max_step = 148

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 149

i = 0
print("Camel6h")

time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    time_data = np.array(data['runtime_' + time_labels[i]])[:,min_step:steps]
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[1] = time
#----------------------------------------------------------------------------------------------------
##FUNCTION Camel 3h
folder = './camel3h/'
file_label = 'camel3h'
d = 2
min_step = 5*d -1
max_step = 149

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']
reps = 10
steps = 149

i = 0
print("Camel3h")

time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    time_data = np.array(data['runtime_'+ time_labels[i]])[:,min_step:steps]
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[2] = time
#---------------------------------------------------------------------------------------------
##FUNCTION Hartmann3
folder = './hart3/'
file_label = 'hart3'
d = 3
min_step = 5*d -1
max_step = 199
steps = 200

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 200

i = 0
print("hart3")
time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    time_data = np.array(data['runtime_' + time_labels[i]])[:,min_step:steps]
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[3] = time
#-------------------------------------------
##FUNCTION Hartmann4
folder = './hart4/'
file_label = 'hart4'
d = 4
min_step = 5*d -1
max_step = 199
steps = 200

alg_labels = ['GP UCB','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI UCB']
regret_labels = ['GPUCB','wgp','DGPBO_EI','MCMC_EI','DGPUCB',]

time_labels = ['GPUCB','WGP','EI','MCMC_EI','DGPUCB']

reps = 10
steps = 200

i = 0
print("hart4")
time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    time_data = np.array(data['runtime_' + time_labels[i]])[:,min_step:steps]
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[4] = time
#-------------------------------------------
##FUNCTION Mich 10d
folder = './mich10/'
file_label = 'mich10'
d = 10
min_step = 5*d -1
max_step = 199

alg_labels = ['GP EI','WGP EI','DGP VI EI','DGP MCMC EI','DGP SI EI']
regret_labels = ['GPEI','wgp','DGPBO_EI','MCMC_EI','DGPSIEI',]

time_labels = ['GPEI','WGP','EI','MCMC_EI','DGPSIEI']


reps = 5
steps = 149
i = 0

print("mich10d")
time = np.zeros((n_algos,steps-min_step))
for label in alg_labels:
    file = folder+file_label+' ' + label+'.mat'
    data = sio.loadmat(file)
    time_data = np.array(data['runtime_' + time_labels[i]])[:,min_step:steps]
    time_data = np.nan_to_num(time_data)
    time[i,:] = np.mean(time_data[:],axis = 0)
    i = i + 1
    print(i)

time_mean_full[5] = time
#-------------------------------------------
# Out:
# ART1
# 1
# 2
# 3
# 4
# 5
# Camel6h
# 1
# 2
# 3
# 4
# 5
# Camel3h
# 1
# 2
# 3
# 4
# 5
# hart3
# 1
# 2
# 3
# 4
# 5
# hart4
# 1
# 2
# 3
# 4
# 5
# mich10d
# 1
# 2
# 3
# 4
# 5
# /home/smartlab/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:179: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)

# %%
for idx in range(6):
    print(plt_titles[idx])
    for i in range(regrets_mean_full[idx].shape[0]):
        print(np.nanmean(time_mean_full[idx][i,:]))
# Out:
# Test Function (1D)
# 0.06159368728597959
# 0.7442138247191906
# 5.46987032815814
# 2.131755208333334
# 3.3712065202494466
# Six-Hump Camel Function
# 0.1641813391404186
# 1.5874144012121845
# 6.62260059246914
# 76.73306363760996
# 24.477810405655728
# Three-Hump Camel Function
# 0.25072932963748634
# 1.1377024439599017
# 6.631728335593244
# 80.28264676258992
# 24.98862367070836
# Hartmann3 Function
# 0.21531979934589282
# 1.654179272909422
# 10.129633585311273
# 157.4055291891892
# 48.26764728494593
# Hartmann4 Function
# 0.25578977134492664
# 2.157671124405331
# 7.392676901684869
# 250.56176444444432
# 89.33428978496129
# Michalewicz Function
# 0.44026565265655504
# 1.6841479630470277
# 8.03298412322998
# 148.71139399999996
# 34.295154513835904

# %%
plt_titles = ['Test Function (1D)','Six-Hump Camel Function','Three-Hump Camel Function','Hartmann3 Function','Hartmann4 Function','Michalewicz Function']
fig,axs = plt.subplots(2,3)
min_steps= [2,9,9,14,29,49]

bar_names= ['GP-BO','WGP-BO','DGP-DSVI-BO','DGP-MCMC-BO','DGP-SI-BO \n (Proposed)']
plt_labels = ['GP-BO','WGP-BO','DGP-DSVI-BO','DGP-SI-BO (Proposed)','DGP-MCMC-BO']
colors = ['b','m','g','k','r']
symbols = ['-o','-p','-x',':','-*']

a = 30
b = 15
#--------------------------
idx = 0
ax = axs[0,0]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (seconds)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)

#--------------------------
idx = 1
ax = axs[0,1]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar/3600,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (hours)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)


#--------------------------
idx = 2
ax = axs[0,2]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar/3600,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (hours)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)


#--------------------------
idx = 3
ax = axs[1,0]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar/3600,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (hours)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)


#--------------------------
idx = 4
ax = axs[1,1]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar/3600,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (hours)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)

#--------------------------
idx = 5
ax = axs[1,2]
ax.figure.set_size_inches(a,b)

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# i = regrets_mean_full[idx].shape[0]-2
# time_bar[i] = np.sum(time_mean_full[idx][i+1,min_step:])
# i = regrets_mean_full[idx].shape[0]-1
# time_bar[i] = np.sum(time_mean_full[idx][i-1,min_step:])

ax.bar(bar_names,time_bar/3600,color = colors, width = 1.0,align = 'edge')
ax.tick_params(axis = 'x',labelsize = 24,labelrotation=45)
ax.set_ylabel('Time (hours)',fontsize = 24)
ax.set_title(plt_titles[idx],fontsize = 30)
ax.tick_params(axis = 'y',labelsize = 20)

# ax.legend(loc=1,fontsize = 20)
# ax.set_ylabel('Simple Regret',fontsize = 24)
# ax.set_xlabel('Number of Evaluations',fontsize=24)
# ax.set_title(plt_titles[idx],fontsize = 30)
# ax.tick_params(axis = 'x',labelsize = 20)
# ax.tick_params(axis = 'y',labelsize = 20)



fig.subplots_adjust(wspace = 0.3,hspace = 0.6)
plt.savefig('Analytical_Time_bars.pdf', format='pdf',pad_inches=0,bbox_inches= 'tight')
# plt.savefig('Analytical_Time_bars.svg', format='svg',transparent = True,pad_inches=0)

# %%
idx = 0

time_bar = np.zeros((regrets_mean_full[idx].shape[0],))

for i in range(regrets_mean_full[idx].shape[0]):
        time_bar[i] = np.sum(time_mean_full[idx][i,min_step:])

# %%
time_bar
# Out:
# array([1.75528526e-03, 4.81972265e-01, 3.34324262e+01, 2.64754517e+02,
#        0.00000000e+00, 8.40480590e+01])

# %%
time_mean_full[1][1,:]
# Out:
# array([       nan, 0.11350188, 0.11030586, 0.10610816, 0.1163789 ,
#        0.10275023, 0.11889837, 0.11978805, 0.10923648, 0.1260359 ,
#        0.11450977, 0.12617497, 0.12981317, 0.12486315, 0.12372451,
#        0.12456512, 0.11769087, 0.13012593, 0.12468574, 0.1294898 ,
#        0.13945627, 0.12838335, 0.14162693, 0.14898269, 0.18121004,
#        0.15940762, 0.17635081, 0.1874934 , 0.21073668, 0.22896073,
#        0.25225985, 0.25645537, 0.26030309, 0.26242697, 0.28530614,
#        0.28064301, 0.27816858, 0.30740504, 0.27815342, 0.2751961 ,
#        0.25487378, 0.26289375, 0.29951477, 0.2828732 , 0.27611523,
#        0.27992458, 0.27977986, 0.2674031 , 0.28656135, 0.24905398,
#        0.23868766, 0.25113993, 0.2560791 , 0.26803176, 0.26168053,
#        0.21037571, 0.23663671, 0.24665649, 0.26074703, 0.23647664,
#        0.2739634 , 0.19833937, 0.20409386, 0.21245153, 0.17877998,
#        0.21208875, 0.15527315, 0.163467  , 0.18831756, 0.19146655,
# ...

# %%
i = 4
idx = 1
fig,ax = plt.subplots()
ax.plot(range(10,149),time_mean_full[idx][i,1:],'k',label = "DGP-MCMC-BO")
ax.plot(range(10,149),time_mean_full[idx][i+1,1:],'r',label = "DGP-SI-BO (Proposed)")

ax.legend()

# ax.set_yscale('log')
ax.set_ylabel('Time (seconds)',fontsize = 14)
ax.set_xlabel('Size of data',fontsize=14)
ax.set_title(plt_titles[idx],fontsize = 18)
ax.tick_params(axis = 'x',labelsize = 12)
ax.tick_params(axis = 'y',labelsize = 12)

ax.set_xlim([10,148])

# ax.set_yscale('log')
# plt.savefig('Camel6h_SI_MCMC_time.pdf', format='pdf',pad_inches=0)
# Out:
# (10.0, 148.0)
